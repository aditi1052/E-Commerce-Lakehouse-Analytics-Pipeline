# %%
tbl = spark.sql(
    "describe detail ecommerce_project.gold.fact_sales"
)

# %%
display(
    tbl.select(
        "format",
        "numFiles",
        "sizeInBytes",
        "partitionColumns"
    )
)

# %%
# %sql
OPTIMIZE ecommerce_project.gold.fact_sales
ZORDER BY (product_id);

# %%
# %sql
DESCRIBE HISTORY ecommerce_project.gold.fact_sales;

# %%
old_version_df = (
    spark.read
    .format("delta")
    .option("versionAsOf", 4)
    .table("ecommerce_project.gold.fact_sales")
)

print("Version 4 row count:", old_version_df.count())

# %%
# %sql
ALTER TABLE ecommerce_project.gold.fact_sales
SET TBLPROPERTIES (
  'delta.deletedFileRetentionDuration' = 'interval 14 days'
);

# %%
# %sql
SHOW TBLPROPERTIES ecommerce_project.gold.fact_sales;
