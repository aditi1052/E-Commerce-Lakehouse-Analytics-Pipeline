-- %%
%sql
create catalog if not exists ecommerce_project;

-- %%
%sql
create schema if not exists ecommerce_project.bronze;
create schema if not exists ecommerce_project.silver;
create schema if not exists ecommerce_project.gold;

-- %%
use catalog ecommerce_project;

-- %%
use schema bronze;

-- %%
create volume if not exists source_files;

-- %%
show schemas in ecommerce_project;

-- %%
show volumes;

-- %%
list '/Volumes/ecommerce_project/bronze/source_files/';
